# %%
import pandas as pd 
from cl_cleaning import CleaningText as ct 
pd.set_option('float_format', '{:,.2f}'.format)
pd.set_option('display.max_columns', 70)

# %%
f3 = pd.read_excel('input/Seguimiento_F3.xlsx', sheet_name='DATA_F3',  dtype='object')

# %%
f3 = ct.norm_header(f3)
path_intermedio = f'output/db-pbi/data_f3-inter.csv'
f3.to_csv(path_intermedio, sep=';', index=False)

# %%
f3 = pd.read_csv('output/db-pbi/data_f3-inter.csv', sep=';', dtype='object')

# %%
def drop_except(df, cols):
    df.drop(df.columns.difference(cols), axis=1, inplace=True)
    return df

# %%
req_lista = ['nro_devolucion', 'nro_guia', 'tipo_producto', 'prd_upc', 'desc_linea',
       'desc_sclase', 'sku', 'desc_sku', 'rut_proveedor', 'dv_proveedor',
       'razon_social', 'local_envio', 'desc_local_envio', 'estado', 'fecha_reserva', 
       'fecha_envio', 'cantidad', 'cant_costo', 'cant_venta', 'tipo_documento_para_dev', 
       'folio_f11', 'folio_f12', 'antiguedad_reservado', 'antiguedad_enviado', 'dias', 'antiguedad', 'fecha_corte', 'grupo']

text_lista = ['tipo_producto', 'desc_linea', 'desc_sclase', 'desc_sku', 'razon_social', 
       'desc_local_envio',  'estado', 'tipo_documento_para_dev','antiguedad', 'grupo']

fnum_lista = ['nro_devolucion', 'nro_guia', 'prd_upc', 'sku', 'rut_proveedor', 'dv_proveedor', 'local_envio', 'folio_f11', 'folio_f12', 'antiguedad_reservado', 
       'antiguedad_enviado',  'dias']

fechas = [ 'fecha_reserva', 'fecha_aprobacion', 'fecha_envio', 'fecha_corte']

# 'cantidad', 'cant_costo', 'cant_venta',

# %%
f3 = drop_except(f3, req_lista)

# %%
print('Limpiando texto en columnas')
f3.loc[:, text_lista] = f3.loc[:, text_lista].apply(ct.clean_str)
# Out:
# Limpiando texto en columnas

# %%
print('Convirtiendo a número parte 1')
f3.loc[:, fnum_lista] = f3.loc[:, fnum_lista].apply(ct.clean_fnum)
# Out:
# Convirtiendo a número parte 1

# %%
f3.head()
# Out:
#   nro_devolucion nro_guia tipo_producto        prd_upc     desc_linea  \
# 0       32534306   195050      producto  2003409003007  electro hogar
# 1       32660579   207155  market place  7702271817488  electro hogar
# 2       32646429   205174  market place  7702271817488  electro hogar
# 3       32683653   208184  market place  7702271817716  electro hogar
# 4       32668933   206879      producto  2004133636004     dormitorio
#
#            desc_sclase      sku                                   desc_sku  \
# 0        plancha vapor  3409003                     ec-plancha silver star
# 1  audifonos bluetooth  5425995        audifonos bluetooth recargables vta
# 2  audifonos bluetooth  5425995        audifonos bluetooth recargables vta
# 3  audifonos bluetooth  5425997  audifonos recargables bluetooth vta negro
# 4   cama americana 15p  4133636     dv s comb rem blan gris europocket 120
#
#   rut_proveedor dv_proveedor          razon_social local_envio  \
# 0     860500260            4   mueblimaquinas ltda        9901
# 1     800078108            4         more products         183
# 2     800078108            4         more products          72
# 3     800078108            4         more products          85
# 4     900737228          NaN  colchones rem s.a.s.          82
#
#   desc_local_envio   estado        fecha_reserva          fecha_envio  \
# 0        cd bogota  enviado  2020-01-30 00:00:00  2020-01-30 00:00:00
# 1         santa fe  enviado  2020-11-20 00:00:00  2020-11-29 00:00:00
# 2     la felicidad  enviado  2020-11-02 00:00:00  2020-11-02 00:00:00
# 3            titan  enviado  2020-12-15 00:00:00  2020-12-15 00:00:00
# 4         hayuelos  enviado  2020-11-26 00:00:00  2020-11-26 00:00:00
#
#   cantidad cant_costo cant_venta tipo_documento_para_dev folio_f11 folio_f12  \
# 0        1     394500     609700                     nan       NaN       NaN
# 1        1      49900      49900                     nan       NaN       NaN
# 2        1      34900      49900                     nan       NaN       NaN
# 3        1      57900      59900                     nan       NaN       NaN
# 4        1     436891    1079900                     nan       NaN       NaN
#
#   antiguedad_reservado antiguedad_enviado dias             antiguedad  \
# 0                  NaN                368  368      7.mas de 360 dias
# 1                  NaN                 64   64   4.entre 61 y 90 dias
# 2                  NaN                 91   91  5.entre 91 y 180 dias
# 3                  NaN                 48   48   3.entre 31 y 60 dias
# 4                  NaN                 67   67   4.entre 61 y 90 dias
#
#   fecha_corte   grupo
# 0  2021-01-31      cd
# 1  2021-01-31  tienda
# 2  2021-01-31  tienda
# 3  2021-01-31  tienda
# 4  2021-01-31  tienda

# %%
f3.fecha_corte.unique()
# Out:
# array(['2021-01-31', '2020-12-27', '2021-02-08', '2021-02-14',
#        '2021-02-21', '2021-02-28', '2021-03-01', '2021-03-08',
#        '2021-03-17', '2021-03-23', '2021-04-07', '2021-04-12',
#        '2021-05-27', '2021-05-11', '2021-05-21', '2021-05-25',
#        '2021-06-01', '2021-06-08', '2021-06-23', '2021-07-29',
#        '2021-07-15', '2021-07-21', '2021-07-28', '2021-08-02',
#        '2021-08-09'], dtype=object)

# %%
f3.fecha_corte =  pd.to_datetime(f3.fecha_corte)

# %%
f3.cant_costo = pd.to_numeric(f3.cant_costo)
f3.cant_costo = round(f3.cant_costo)
f3.cant_costo = f3.cant_costo.astype(int)

# %%
f3.cantidad = pd.to_numeric(f3.cantidad)
f3.cantidad = round(f3.cantidad)
f3.cantidad = f3.cantidad.fillna(0)
f3.cantidad = f3.cantidad.astype(int)

# %%
f3.cant_venta = pd.to_numeric(f3.cant_venta)
f3.cant_venta = round(f3.cant_venta)
f3.cant_venta = f3.cant_venta.fillna(0)
f3.cant_venta = f3.cant_venta.astype(int)

# %%
f3.head()
# Out:
#   nro_devolucion nro_guia tipo_producto        prd_upc     desc_linea  \
# 0       32534306   195050      producto  2003409003007  electro hogar
# 1       32660579   207155  market place  7702271817488  electro hogar
# 2       32646429   205174  market place  7702271817488  electro hogar
# 3       32683653   208184  market place  7702271817716  electro hogar
# 4       32668933   206879      producto  2004133636004     dormitorio
#
#            desc_sclase      sku                                   desc_sku  \
# 0        plancha vapor  3409003                     ec-plancha silver star
# 1  audifonos bluetooth  5425995        audifonos bluetooth recargables vta
# 2  audifonos bluetooth  5425995        audifonos bluetooth recargables vta
# 3  audifonos bluetooth  5425997  audifonos recargables bluetooth vta negro
# 4   cama americana 15p  4133636     dv s comb rem blan gris europocket 120
#
#   rut_proveedor dv_proveedor          razon_social local_envio  \
# 0     860500260            4   mueblimaquinas ltda        9901
# 1     800078108            4         more products         183
# 2     800078108            4         more products          72
# 3     800078108            4         more products          85
# 4     900737228          NaN  colchones rem s.a.s.          82
#
#   desc_local_envio   estado        fecha_reserva          fecha_envio  \
# 0        cd bogota  enviado  2020-01-30 00:00:00  2020-01-30 00:00:00
# 1         santa fe  enviado  2020-11-20 00:00:00  2020-11-29 00:00:00
# 2     la felicidad  enviado  2020-11-02 00:00:00  2020-11-02 00:00:00
# 3            titan  enviado  2020-12-15 00:00:00  2020-12-15 00:00:00
# 4         hayuelos  enviado  2020-11-26 00:00:00  2020-11-26 00:00:00
#
#   cantidad  cant_costo  cant_venta tipo_documento_para_dev folio_f11  \
# 0        1      394500      609700                     nan       NaN
# 1        1       49900       49900                     nan       NaN
# 2        1       34900       49900                     nan       NaN
# 3        1       57900       59900                     nan       NaN
# 4        1      436891     1079900                     nan       NaN
#
#   folio_f12 antiguedad_reservado antiguedad_enviado dias  \
# 0       NaN                  NaN                368  368
# 1       NaN                  NaN                 64   64
# 2       NaN                  NaN                 91   91
# 3       NaN                  NaN                 48   48
# 4       NaN                  NaN                 67   67
#
#               antiguedad fecha_corte   grupo
# 0      7.mas de 360 dias  2021-01-31      cd
# 1   4.entre 61 y 90 dias  2021-01-31  tienda
# 2  5.entre 91 y 180 dias  2021-01-31  tienda
# 3   3.entre 31 y 60 dias  2021-01-31  tienda
# 4   4.entre 61 y 90 dias  2021-01-31  tienda

# %%
f3.cantidad.isna().sum()
# Out:
# 0

# %%
f3.to_csv('output/210812-1535-data_f3.csv', sep=';', index=False)

# %% [markdown]
# # F4

# %%
import pandas as pd 
from cl_cleaning import CleaningText as ct 
from datetime import datetime

dt_string = datetime.now().strftime('%y%m%d-%H%M')

f4 = pd.read_excel('input/Seguimiento_F4.xlsx', sheet_name='DATA',  dtype='object')
path_intermedio = f'output/db-pbi/{dt_string}-data_f4-inter.csv'
f4 = ct.norm_header(f4)
f4.to_csv(path_intermedio, sep=';', index=False)

# %%
path_intermedio = f'output/db-pbi/210812-1604-data_f4-inter.csv'
f4 = pd.read_csv(path_intermedio, sep=';', dtype='object')

# %%
f4.columns
# Out:
# Index(['nro_red_inventario', 'local', 'desc_local', 'estado', 'tipo_redinv',
#        'fecha_creacion', 'usuario_creacion', 'fecha_reserva',
#        'usuario_reserva', 'fecha_envio', 'usuario_envio', 'destino',
#        'rut_destino', 'centro_de_costos', 'desccentro_e_costo', 'linea',
#        'descripcion_linea', 'subclase', 'descripcion_subclase', 'nro_producto',
#        'descripcion_producto', 'upc', 'cantidad', 'precio_vta', 'precio_costo',
#        'total_precio_vta', 'total_precio_costo', 'fecha_corte',
#        'posible_causa', 'aplica', 'fecha_inventario', 'validar', 'validar_2',
#        'observacion', 'grupo_tipo_f4', 'grupo'],
#       dtype='object')

# %%
req_lista = ['nro_red_inventario', 'local', 'desc_local', 'estado', 'tipo_redinv',
       'fecha_creacion', 'usuario_creacion', 'fecha_reserva',
       'usuario_reserva', 'fecha_envio', 'usuario_envio', 'destino',
       'rut_destino', 'centro_de_costos', 'desccentro_e_costo', 'linea',
       'descripcion_linea', 'subclase', 'descripcion_subclase', 'nro_producto',
       'descripcion_producto', 'upc', 'cantidad', 'precio_vta', 'precio_costo',
       'total_precio_vta', 'total_precio_costo', 'fecha_corte',
       'posible_causa', 'fecha_inventario', 'observacion', 'grupo_tipo_f4', 'grupo']

text_lista = ['desc_local', 'estado', 'tipo_redinv', 'usuario_creacion', 'usuario_reserva', 
    'usuario_envio', 'destino', 'desccentro_e_costo', 'linea','descripcion_linea', 'subclase', 
    'descripcion_subclase',  'descripcion_producto', 'posible_causa',  'observacion', 'grupo_tipo_f4', 'grupo']

fnum_lista = ['nro_red_inventario',  'local',  'rut_destino', 'centro_de_costos', 'nro_producto', 'upc', 'cantidad', ]

fechas = [ 'fecha_creacion', 'fecha_reserva', 'fecha_envio', 'fecha_corte']

# 'fecha_inventario' 

# 'validar', 'validar_2'

# 'precio_vta', 'precio_costo', 'total_precio_vta', 'total_precio_costo',

# %%
f4 = drop_except(f4, req_lista)

# %%
print('Limpiando texto en columnas')
f4.loc[:, text_lista] = f4.loc[:, text_lista].apply(ct.clean_str)

print('Convirtiendo a número parte 1')
f4.loc[:, fnum_lista] = f4.loc[:, fnum_lista].apply(ct.clean_fnum)
# Out:
# Limpiando texto en columnas
# Convirtiendo a número parte 1

# %%
def replace_date(col):
    col = col.str.replace('ene', '01')
    col = col.str.replace('feb', '02')
    col = col.str.replace('mar', '03')
    col = col.str.replace('abr', '04')
    col = col.str.replace('may', '05')
    col = col.str.replace('jun', '06')
    col = col.str.replace('jul', '07')
    col = col.str.replace('ago', '08')
    col = col.str.replace('sep', '09')
    col = col.str.replace('oct', '10')
    col = col.str.replace('nov', '11')
    col = col.str.replace('dic', '12')
    return col

# %%
def na_date(col):
    col.fillna('01-01-1990', inplace = True)
    return col

# %%
def to_date_format1(col):
    col = pd.to_datetime(col, format='%Y-%m-%d')
    return col

# %%
def to_date_format2(col):
    col = pd.to_datetime(col, format='%d-%m-%Y')
    return col

# %%
f4.loc[:, fechas] = f4.loc[:, fechas].apply(na_date)

# %%
f4.loc[:, fechas] = f4.loc[:, fechas].apply(replace_date)

# %%
f4aux = f4.copy()

# %%
f4.fecha_creacion = pd.to_datetime(f4.fecha_creacion)
f4.fecha_reserva = pd.to_datetime(f4.fecha_reserva)
f4.fecha_envio = pd.to_datetime(f4.fecha_envio)
f4.fecha_corte = pd.to_datetime(f4.fecha_corte)
f4.fecha_inventario = pd.to_datetime(f4.fecha_inventario)

# %%
f4.head()
# Out:
#   nro_red_inventario local desc_local   estado    tipo_redinv fecha_creacion  \
# 0           46056177    93    cacique  enviado  gasto externo     2021-01-02
# 1           46056177    93    cacique  enviado  gasto externo     2021-01-02
# 2           46056177    93    cacique  enviado  gasto externo     2021-01-02
# 3           46056368    25   fontanar  enviado  gasto externo     2021-01-02
# 4           46056368    25   fontanar  enviado  gasto externo     2021-01-02
#
#                       usuario_creacion fecha_reserva  \
# 0             yesenia cespedes pereira    2021-02-01
# 1             yesenia cespedes pereira    2021-02-01
# 2             yesenia cespedes pereira    2021-02-01
# 3  mayra  alejandra bohorquez gonzalez    2021-02-01
# 4  mayra  alejandra bohorquez gonzalez    2021-02-01
#
#                        usuario_reserva fecha_envio  \
# 0             yesenia cespedes pereira  2021-02-01
# 1             yesenia cespedes pereira  2021-02-01
# 2             yesenia cespedes pereira  2021-02-01
# 3  mayra  alejandra bohorquez gonzalez  2021-02-01
# 4  mayra  alejandra bohorquez gonzalez  2021-02-01
#
#                          usuario_envio                    destino rut_destino  \
# 0             yesenia cespedes pereira                  falabella  9000174478
# 1             yesenia cespedes pereira                  falabella  9000174478
# 2             yesenia cespedes pereira                  falabella  9000174478
# 3  mayra  alejandra bohorquez gonzalez  falabella de colombia s.a  9000174478
# 4  mayra  alejandra bohorquez gonzalez  falabella de colombia s.a  9000174478
#
#   centro_de_costos desccentro_e_costo linea descripcion_linea   subclase  \
# 0            41301                mkp   j11     electro hogar  j11010202
# 1            41301                mkp   j11     electro hogar  j11021301
# 2            41301                mkp   j11     electro hogar  j11140406
# 3            41301                mkp   j11     electro hogar  j11021301
# 4            41301                mkp   j16        decoracion  j16040203
#
#         descripcion_subclase nro_producto  \
# 0      plasmas 50 o mas pulg      5065102
# 1        audifonos bluetooth      9347735
# 2                     drones      4964221
# 3        audifonos bluetooth      4964011
# 4  organizacion refrigerador      4079214
#
#                                 descripcion_producto            upc cantidad  \
# 0  televisor lg 50 pulgadas 50um7300 smart tv uhd 4k  2005065102001        1
# 1         audifonos motorola  earbuds pace 105 negro  5012786038493        2
# 2    mini drone control camara hd wifi led storm 033  4885016893886        1
# 3      audifonos bluetooth inalambricos cargador i9s   635414205156        4
# 4  purificador de agua filtro bioenergetico biowater   658939618362        1
#
#   precio_vta precio_costo total_precio_vta total_precio_costo fecha_corte  \
# 0    2199900      2199900          2199900            2199900  2021-01-31
# 1      25900        25900            51800              51800  2021-01-31
# 2     159900       159900           159900             159900  2021-01-31
# 3      44900        44900           179600             179600  2021-01-31
# 4     299800       299800           299800             299800  2021-01-31
#
#   posible_causa fecha_inventario          observacion  grupo_tipo_f4   grupo
# 0           nan       2021-01-13  antes de inventario  gasto externo  tienda
# 1           nan       2021-01-13  antes de inventario  gasto externo  tienda
# 2           nan       2021-01-13  antes de inventario  gasto externo  tienda
# 3           nan       2021-01-08  antes de inventario  gasto externo  tienda
# 4           nan       2021-01-08  antes de inventario  gasto externo  tienda

# %%
f4.to_csv('output/data_seguimiento_f4.csv', sep=';', index=False)

# %%
cua = pd.read_csv('input/210817-1501-f4-output.csv', sep=';', dtype='object')

# %%
req_lista = ['nro_red_inventario', 'local', 'desc_local', 'estado', 'tipo_redinv',
       'fecha_creacion', 'usuario_creacion', 'fecha_reserva',
       'usuario_reserva', 'fecha_envio', 'usuario_envio', 'destino',
       'rut_destino', 'centro_de_costos', 'desccentro_e_costo', 'linea',
       'descripcion_linea', 'subclase', 'descripcion_subclase', 'nro_producto',
       'descripcion_producto', 'upc', 'cantidad', 'precio_vta', 'precio_costo',
       'total_precio_vta', 'total_precio_costo']

text_lista = ['desc_local', 'estado', 'tipo_redinv', 'usuario_creacion', 'usuario_reserva', 
    'usuario_envio', 'destino', 'desccentro_e_costo', 'linea','descripcion_linea', 'subclase', 
    'descripcion_subclase',  'descripcion_producto']

fnum_lista = ['nro_red_inventario',  'local',  'rut_destino', 'centro_de_costos', 'nro_producto', 'upc', 'cantidad', ]

fechas = [ 'fecha_creacion', 'fecha_reserva', 'fecha_envio', 'fecha_corte']

# 'fecha_inventario' 

# 'validar', 'validar_2'

# 'precio_vta', 'precio_costo', 'total_precio_vta', 'total_precio_costo',

# %%
cua = ct.norm_header(cua)

# %%
cua = drop_except(cua, req_lista)
print('Limpiando texto en columnas')
cua.loc[:, text_lista] = cua.loc[:, text_lista].apply(ct.clean_str)

print('Convirtiendo a número parte 1')
cua.loc[:, fnum_lista] =cua.loc[:, fnum_lista].apply(ct.clean_fnum)
# Out:
# Limpiando texto en columnas
# Convirtiendo a número parte 1

# %%
cua['fecha_corte'] = '17-08-2021'

# %%
cua.loc[:, fechas] = cua.loc[:, fechas].apply(na_date)
cua.loc[:, fechas] = cua.loc[:, fechas].apply(replace_date)

# %%
cua.fecha_creacion = pd.to_datetime(cua.fecha_creacion)
cua.fecha_reserva = pd.to_datetime(cua.fecha_reserva)
cua.fecha_envio = pd.to_datetime(cua.fecha_envio)
cua.fecha_corte = pd.to_datetime(cua.fecha_corte)

# %%
costos = [ 'precio_vta', 'precio_costo', 'total_precio_vta', 'total_precio_costo']

# %%
cua.loc[:,costos] = cua.loc[:,costos].apply(lambda x: x.str.replace(',','.'))

# %%
cua.loc[:,costos] = cua.loc[:,costos].apply(pd.to_numeric)

# %%
cua.head()
# Out:
#   nro_red_inventario local desc_local     estado tipo_redinv fecha_creacion  \
# 0           46069542    53   galerias  reservado  materiales     2021-01-18
# 1           46069542    53   galerias  reservado  materiales     2021-01-18
# 2           46069542    53   galerias  reservado  materiales     2021-01-18
# 3           46069542    53   galerias  reservado  materiales     2021-01-18
# 4           46069542    53   galerias  reservado  materiales     2021-01-18
#
#                      usuario_creacion fecha_reserva  \
# 0  eduardo andres hernandez casilimas    2021-01-18
# 1  eduardo andres hernandez casilimas    2021-01-18
# 2  eduardo andres hernandez casilimas    2021-01-18
# 3  eduardo andres hernandez casilimas    2021-01-18
# 4  eduardo andres hernandez casilimas    2021-01-18
#
#                       usuario_reserva fecha_envio usuario_envio destino  \
# 0  eduardo andres hernandez casilimas  1990-01-01           nan     nan
# 1  eduardo andres hernandez casilimas  1990-01-01           nan     nan
# 2  eduardo andres hernandez casilimas  1990-01-01           nan     nan
# 3  eduardo andres hernandez casilimas  1990-01-01           nan     nan
# 4  eduardo andres hernandez casilimas  1990-01-01           nan     nan
#
#   rut_destino centro_de_costos  desccentro_e_costo linea descripcion_linea  \
# 0  9000174478             2360  cc tienda galerias   j99    administracion
# 1  9000174478             2360  cc tienda galerias   j99    administracion
# 2  9000174478             2360  cc tienda galerias   j99    administracion
# 3  9000174478             2360  cc tienda galerias   j99    administracion
# 4  9000174478             2360  cc tienda galerias   j99    administracion
#
#     subclase              descripcion_subclase nro_producto  \
# 0  j99140101            articulo de escritorio      3577678
# 1  j99140409      otros materiales de embalaje      3426096
# 2  j99140502               etiquetas adhesivas      3897643
# 3  j99140102           papeleria institucional      3533671
# 4  j99140601  bolsas plasticas institucionales      3771739
#
#                 descripcion_producto            upc cantidad  precio_vta  \
# 0                   borrador de nata  2003577678007        1      429.00
# 1     plastico burbuja 1.50 x 50 mts  2003426096006        4   32,600.00
# 2  etq adh 0x0 7.6x4.1 blanca  r3000  2003897643006     6000        8.00
# 3       ultimas unidades media carta  2003533671004        1   15,000.00
# 4               bolsa con fuelle nue  2003771739009      250      347.00
#
#    precio_costo  total_precio_vta  total_precio_costo fecha_corte
# 0        423.14            429.00              423.14  2021-08-17
# 1     37,191.17        130,400.00          148,764.66  2021-08-17
# 2          7.21         48,000.00           43,248.00  2021-08-17
# 3     15,351.73         15,000.00           15,351.73  2021-08-17
# 4        347.00         86,750.00           86,750.00  2021-08-17

# %%
fsave = pd.concat([f4, cua], axis=0)

# %%
fsave.shape
# Out:
# (732798, 33)

# %%
fsave.to_csv('output/data_seguimiento_f4.csv', sep=';', index=False)

# %% [markdown]
# ## F3 planilla

# %%
tre = pd.read_csv('input/210817-1530-f3-output.csv', sep=';', dtype='object')

# %%
tre = ct.norm_header(tre)

# %%
tre = tre.rename(columns={'upc':'prd_upc', 'descripcion':'desc_sku' , 'descripcion1':'desc_sclase', 'descripcion4':'desc_linea', 
       'proveedor':'razon_social', 'local':'local_envio', 'descripcion5':'desc_local_envio', 'estado':'estado_num', 
       'descripcion6':'estado', 'cant*costo':'cant_costo', 'cant*precio':'cant_venta' })

# %%
req_lista = ['nro_devolucion', 'nro_guia', 'tipo_producto', 'prd_upc', 'desc_linea',
       'desc_sclase', 'sku', 'desc_sku', 'rut_proveedor', 'dv_proveedor',
       'razon_social', 'local_envio', 'desc_local_envio', 'estado', 'fecha_reserva', 
       'fecha_envio', 'cantidad', 'cant_costo', 'cant_venta', 'tipo_documento_para_dev', 
       'folio_f11', 'folio_f12']

text_lista = ['tipo_producto', 'desc_linea', 'desc_sclase', 'desc_sku', 'razon_social', 
       'desc_local_envio',  'estado', 'tipo_documento_para_dev']

fnum_lista = ['nro_devolucion', 'nro_guia', 'prd_upc', 'sku', 'rut_proveedor', 'local_envio', 'folio_f11', 'folio_f12']

fechas = [ 'fecha_reserva', 'fecha_envio']

# 'cantidad', 'cant_costo', 'cant_venta',

# %%
tre = drop_except(tre, req_lista)

# %%
print('Limpiando texto en columnas')
tre.loc[:, text_lista] = tre.loc[:, text_lista].apply(ct.clean_str)

print('Convirtiendo a número parte 1')
tre.loc[:, fnum_lista] =tre.loc[:, fnum_lista].apply(ct.clean_fnum)
# Out:
# Limpiando texto en columnas
# Convirtiendo a número parte 1

# %%
tre = tre.loc[(tre.estado=='reservado') | (tre.estado=='enviado') ]

# %%
treaux = tre.copy()

# %%
tre['fecha_corte'] = '2021-08-17'

# %%
tre.loc[:, fechas] = tre.loc[:, fechas].apply(na_date)

# %%
tre.loc[:, fechas] = tre.loc[:, fechas].apply(replace_date)

# %%
tre.fecha_reserva = pd.to_datetime(tre.fecha_reserva, format='%d-%m-%Y')
tre.fecha_envio = pd.to_datetime(tre.fecha_envio, format='%d-%m-%Y')

# %%
delta_reservado = pd.to_datetime('today') - tre.fecha_reserva
delta_envio = pd.to_datetime('today') - tre.fecha_envio

# %%
tre['antiguedad_reservado'] =  delta_reservado.dt.days
tre['antiguedad_enviado'] = delta_envio.dt.days

# %%
tre.head()
# Out:
#      nro_devolucion fecha_reserva fecha_envio nro_guia tipo_producto  \
# 63         32850000    2021-04-15  2021-04-15   221379  market place
# 2863       32709100    2021-01-12  1990-01-01      NaN      producto
# 2889       32745900    2021-02-19  2021-02-23   213395  market place
# 2890       32746600    2021-02-19  2021-02-23   213197  market place
# 2891       32747300    2021-02-19  2021-02-23   213233  market place
#
#             prd_upc      sku                                  desc_sku  \
# 63    2004281237009  4281237                   botin negro viola 603 p
# 2863  7707212941420  3706812           ec-mat baby active fitness yoga
# 2889  2009170381009  9170381  silla oficina mobli - 1285 asiento negro
# 2890  2005423997003  5423997                             silla nairobi
# 2891  2005774306004  5774306           silla de oficina colors premium
#
#                desc_sclase desc_linea            razon_social rut_proveedor  \
# 63      botines muj casual    calzado                jumo sas    9011845521
# 2863  accesorios seguridad      ninos         stilotex s.a.s.    8001679192
# 2889     sillas de oficina    muebles      ims industrias sas    9006731967
# 2890     sillas de oficina    muebles  ekonomodo colombia sas    9007546640
# 2891     sillas de oficina    muebles  ekonomodo colombia sas    9007546640
#
#      local_envio desc_local_envio     estado cantidad cant_costo cant_venta  \
# 63           138           colina    enviado        1      79900      79900
# 2863        9901        cd bogota  reservado        1      27256      49900
# 2889        9901        cd bogota    enviado        1     600000     600000
# 2890        9901        cd bogota    enviado        2    1399800    1399800
# 2891        9901        cd bogota    enviado        1     799900     799900
#
#      tipo_documento_para_dev folio_f11    folio_f12 fecha_corte  \
# 63              nota credito       NaN  12636878700  2021-08-17
# 2863            nota credito       NaN  12577538978  2021-08-17
# 2889            nota credito       NaN  12614549196  2021-08-17
# 2890            nota credito       NaN  12577594301  2021-08-17
# 2891            nota credito       NaN  12602424849  2021-08-17
#
#       antiguedad_reservado  antiguedad_enviado
# 63                     125                 125
# 2863                   218               11552
# 2889                   180                 176
# 2890                   180                 176
# 2891                   180                 176

# %%
def get_antiguedad(celda):

    if (celda>=0) & (celda<16):
        return'1. entre 0 y 15 dias'
    elif (celda>=16) & (celda<31):
        return '2.entre 16 y 30 dias'
    elif (celda>=31) & (celda<61):
        return '3.entre 31 y 60 dias'
    elif (celda>=61) & (celda<91):
        return '4.entre 61 y 90 dias'
    elif (celda>=91) & (celda<181):
        return '5.entre 91 y 180 dias'
    elif (celda>=181) & (celda<361):
        return '6.entre 181 y 360 dias'
    else:
        return '7.mas de 360 dias'

# %%
tre.loc[tre.estado=='reservado', 'dias'] = tre.loc[tre.estado=='reservado', 'antiguedad_reservado']
tre.loc[tre.estado=='enviado', 'dias'] = tre.loc[tre.estado=='enviado', 'antiguedad_enviado']

# %%
tre['antiguedad'] = tre.dias.apply(get_antiguedad)

# %%
tre.head()
# Out:
#      nro_devolucion fecha_reserva fecha_envio nro_guia tipo_producto  \
# 63         32850000    2021-04-15  2021-04-15   221379  market place
# 2863       32709100    2021-01-12  1990-01-01      NaN      producto
# 2889       32745900    2021-02-19  2021-02-23   213395  market place
# 2890       32746600    2021-02-19  2021-02-23   213197  market place
# 2891       32747300    2021-02-19  2021-02-23   213233  market place
#
#             prd_upc      sku                                  desc_sku  \
# 63    2004281237009  4281237                   botin negro viola 603 p
# 2863  7707212941420  3706812           ec-mat baby active fitness yoga
# 2889  2009170381009  9170381  silla oficina mobli - 1285 asiento negro
# 2890  2005423997003  5423997                             silla nairobi
# 2891  2005774306004  5774306           silla de oficina colors premium
#
#                desc_sclase desc_linea            razon_social rut_proveedor  \
# 63      botines muj casual    calzado                jumo sas    9011845521
# 2863  accesorios seguridad      ninos         stilotex s.a.s.    8001679192
# 2889     sillas de oficina    muebles      ims industrias sas    9006731967
# 2890     sillas de oficina    muebles  ekonomodo colombia sas    9007546640
# 2891     sillas de oficina    muebles  ekonomodo colombia sas    9007546640
#
#      local_envio desc_local_envio     estado cantidad cant_costo cant_venta  \
# 63           138           colina    enviado        1      79900      79900
# 2863        9901        cd bogota  reservado        1      27256      49900
# 2889        9901        cd bogota    enviado        1     600000     600000
# 2890        9901        cd bogota    enviado        2    1399800    1399800
# 2891        9901        cd bogota    enviado        1     799900     799900
#
#      tipo_documento_para_dev folio_f11    folio_f12 fecha_corte  \
# 63              nota credito       NaN  12636878700  2021-08-17
# 2863            nota credito       NaN  12577538978  2021-08-17
# 2889            nota credito       NaN  12614549196  2021-08-17
# 2890            nota credito       NaN  12577594301  2021-08-17
# 2891            nota credito       NaN  12602424849  2021-08-17
#
#       antiguedad_reservado  antiguedad_enviado   dias              antiguedad
# 63                     125                 125 125.00   5.entre 91 y 180 dias
# 2863                   218               11552 218.00  6.entre 181 y 360 dias
# 2889                   180                 176 176.00   5.entre 91 y 180 dias
# 2890                   180                 176 176.00   5.entre 91 y 180 dias
# 2891                   180                 176 176.00   5.entre 91 y 180 dias

# %%
df_tres = pd.read_csv('output/data_seguimiento_f3.csv', sep=';', dtype='object')

# %%
tsave = pd.concat([df_tres, tre], axis=0)

# %%
tsave.to_csv('output/data_seguimiento_f3.csv', sep=';', index=False)

# %%
tsave.fecha_reserva.unique()
# Out:
# array(['2020-01-30 00:00:00', '2020-11-20 00:00:00',
#        '2020-11-02 00:00:00', ..., Timestamp('2021-08-11 00:00:00'),
#        Timestamp('2021-08-14 00:00:00'), Timestamp('2021-08-16 00:00:00')],
#       dtype=object)

# %%
df_tres.loc[:,fechas] = df_tres.loc[:,fechas].apply(na_date)

# %%
df_tres.loc[:,fechas] = df_tres.loc[:,fechas].apply(replace_date)

# %%
df_tres.loc[:,'fecha_reserva'] = df_tres.loc[:,'fecha_reserva'].str.replace('mrz','03')
