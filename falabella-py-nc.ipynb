# %%
import pandas as pd

# %%
nc = pd.read_excel('input/210630_nc.xlsx', sheet_name='DB')

# %%
nc.head()
# Out:
#      COD_TRX   CAUTORIZA   F_COMPRA  LOCAL_CREACION NLOCAL_CREACION  \
# 0  205246708  1059705755 2021-01-02              19      BUENAVISTA
# 1  205245636  1059717291 2021-01-02              19      BUENAVISTA
# 2  205255000  1059725210 2021-01-02              56       LA CAROLA
# 3  205259670  1059758904 2021-01-02              56       LA CAROLA
# 4  205259670  1059758904 2021-01-02              56       LA CAROLA
#
#    NRO_TERM_NVA  SEC_NVA  CVEND_NVO  LOCAL_ANT             NLOCAL_ANT  ...  \
# 0            26     3171     924121       2000  TIENDA FALABELLA .COM  ...
# 1            19     3342     103500         19             BUENAVISTA  ...
# 2             8     8605     959618       2000  TIENDA FALABELLA .COM  ...
# 3            18     3687     937312         56              LA CAROLA  ...
# 4            18     3687     937312         56              LA CAROLA  ...
#
#     NIT_PROV                 NOMBRE_PROVEEDOR  LINEA       DESC_LINEA  \
# ...

# %%
pd.set_option('float_format', '{:,.2f}'.format)
pd.set_option('display.max_columns', 70)

# %%
nc.to_csv(f'output/210713-nc.csv', sep=';', index=False)

# %%
nc2 = pd.read_csv(f'output/210713-nc.csv', sep=';', dtype='object')

# %%
nc2.head()
# Out:
#      COD_TRX   CAUTORIZA    F_COMPRA LOCAL_CREACION NLOCAL_CREACION  \
# 0  205246708  1059705755  2021-01-02             19      BUENAVISTA
# 1  205245636  1059717291  2021-01-02             19      BUENAVISTA
# 2  205255000  1059725210  2021-01-02             56       LA CAROLA
# 3  205259670  1059758904  2021-01-02             56       LA CAROLA
# 4  205259670  1059758904  2021-01-02             56       LA CAROLA
#
#   NRO_TERM_NVA SEC_NVA CVEND_NVO LOCAL_ANT             NLOCAL_ANT  \
# 0           26    3171    924121      2000  TIENDA FALABELLA .COM
# 1           19    3342    103500        19             BUENAVISTA
# 2            8    8605    959618      2000  TIENDA FALABELLA .COM
# 3           18    3687    937312        56              LA CAROLA
# 4           18    3687    937312        56              LA CAROLA
#
#   F_COMPRA_ANT NRO_TERM_ANT SEC_ANT CVEND_ANT    CC_CLIENTE          SKU  \
# 0   2020-12-04         3463   29741    924121    42899948.0    9573486.0
# ...

# %%
pd.unique(nc2['NLOCAL_CREACION'])
# Out:
# array(['BUENAVISTA', 'LA CAROLA', 'LA FELICIDAD', 'COLINA', 'FONTANAR',
#        'ACQUA', 'CARACOLI', 'EL CASTILLO', 'FALABELLA. COM ALTERNO',
#        'TITAN', 'CENTRO MAYOR', 'UNICENTRO', 'GALERIAS', 'HAYUELOS',
#        'SUBA', 'SANTA FE', 'PLAZA CENTRAL', 'DIVER PLAZA',
#        'MARTINA FONTANAR', 'CACIQUE', 'VILLA COUNTRY', 'PARQUE ARBOLEDA',
#        'PRIMAVERA', 'SANTAFE MEDELLIN', 'ARKADIA', 'JARDIN PLAZA',
#        'WTC CALI', 'SAN DIEGO', 'TIENDA FALABELLA .COM', 'VENTA EMPRESA',
#        'Crate and Barrel Colina', 'ADMINISTRATIVO',
#        'Crate and Barrel Online', 'MARTINA EL TESORO', 'MARTINA COLINA',
#        'C&B Online ADMINISTRATIVO'], dtype=object)
