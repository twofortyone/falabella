# %%
import pandas as pd
pd.set_option('display.max_columns', 70)
pd.set_option('display.max_rows',150)

# %%
df = pd.read_csv('input/planillas/210830_f11_1.csv', sep=';', dtype='object')

# %%
def gr(df3, dfna):
    df = df3.copy()
    i = 0
    idf=0
    while i < dfna.shape[0]:
        i = dfna.index[idf]
        df.iloc[i-4,21] = dfna.iloc[idf-2,1:2].values[0]
        df.iloc[i-4,22:27] = dfna.iloc[idf-1,1:6].values
        df.iloc[i-4,27:49] = dfna.iloc[idf,1:23].values
        idf+=3
    return df

# %%
def grdos(dfarg, dfna):
    df = dfarg.copy()
    i = 0
    idf=0
    while idf < dfna.shape[0]:
        i = dfna.index[idf]
        df.iloc[i-2,3] = df.iloc[i-1,1]
        df.iloc[i-2,4:6] = df.iloc[i,1:3].values
        df.iloc[i-2,6:21] = df.iloc[i+1,1:16].values
        idf+=1
    return df

# %% [markdown]
# Limpieza parte 1

# %%
dfnull = df[df.isnull().all(axis=1)]
df = df[~df.isnull().all(axis=1)].reset_index(drop=True)

# %% [markdown]
# Limpieza parte 2

# %%
dfna = df[df['Nro. F11'].isna()]
idfna = dfna.index.values 

dfnacliente = df.loc[(df['Nro. F11'].isna())&((df['F03 Asociado']=='CLIENTE')|(df['F03 Asociado']=='EMPRESA'))]
index_dfnac = dfnacliente.index

menosuno = (index_dfnac-1).isin(idfna)
menosdos = (index_dfnac-2).isin(idfna)

oklist = []
for i in range(len(index_dfnac)): 
    oklist.append((menosuno[i]==True) & (menosdos[i]==True))
    
itochange = index_dfnac[oklist]

acamb = dfnacliente.loc[itochange]

df2 = gr(df, acamb)
iuno = acamb.index.values
idos = acamb.index.values-1
itres = acamb.index.values-2
df3 = df2.loc[~df2.index.isin(iuno)]
df3 = df3.loc[~df3.index.isin(idos)]
df3 = df3.loc[~df3.index.isin(itres)]
df3.reset_index(drop=True, inplace=True)

dfuno = df.loc[(df.index.isin(iuno))|(df.index.isin(idos))|(df.index.isin(itres))]
dfuno.to_excel(f'output/df-deleted-1.xlsx', sheet_name=f'f11', index=False)

# %%
#dfnacliente.to_excel(f'output/dfna-2.xlsx', sheet_name=f'f11', index=False)

# %% [markdown]
# Limpieza parte 2

# %%
dfna = df3[df3['Nro. F11'].isna()]

indexdigit = df3.loc[(df3['Nro. F11'].isna())&(df3['F03 Asociado'].str.isdigit())].index

index_dfna = dfna.index.values
masuno = (indexdigit+1).isin(index_dfna)
menosuno = (indexdigit-1).isin(index_dfna)

oklist = []
for i in range(len(indexdigit)): 
    oklist.append((masuno[i]==True) & (menosuno[i]==True))
    
itochange = indexdigit[oklist]

# %%
acamb = dfna.loc[itochange]
df4 = grdos(df3, acamb)
iuno = acamb.index.values-1
idos = acamb.index.values
itres = acamb.index.values+1
df4 = df4.loc[~df4.index.isin(iuno)]
df4 = df4.loc[~df4.index.isin(idos)]
df4 = df4.loc[~df4.index.isin(itres)]
df4.reset_index(drop=True, inplace=True)

dfdos = df3.loc[(df3.index.isin(iuno))|(df3.index.isin(idos))|(df3.index.isin(itres))]
dfdos.to_excel(f'output/df-deleted-2.xlsx', sheet_name=f'f11', index=False)

# %% [markdown]
# Limpieza parte 3

# %%
bogota = df4.loc[(df4['Nro. F11'].isna())&(df4['F03 Asociado']=='BOGOTA')]

for i in bogota.index:
    df4.iloc[i-1,22:27] = df4.iloc[i,1:6].values
    
df5 = df4[~df4.index.isin(bogota.index)].reset_index(drop=True)

# %% [markdown]
# cliente/empresa

# %%
cliente_empresa = df5.loc[(df5['Nro. F11'].isna())&((df5['F03 Asociado']=='CLIENTE')|(df5['F03 Asociado']=='EMPRESA'))]

for i in cliente_empresa.index:
    df5.iloc[i-1,27:49] = df5.iloc[i,1:23].values
    
df6 = df5[~df5.index.isin(cliente_empresa.index)].reset_index(drop=True)

# %% [markdown]
# direccion

# %%
direc = df6.loc[(~df6['F03 Asociado'].str.isdigit().fillna(False))&(df6['Nro. F11'].isna())&(df6['F03 Asociado']!='CD FALABELLA')]

for i in direc.index:
    df6.iloc[i-1,21:27] = df6.iloc[i,1:7].values
    df6.iloc[i-1,27:49] = df6.iloc[i,27:49].values
    
df7 = df6[~df6.index.isin(direc.index)].reset_index(drop=True)

# %% [markdown]
# Guardar archivos

# %%
#df3.to_excel(f'output/df3.xlsx', sheet_name=f'f11', index=False) 
#df4.to_excel(f'output/df4.xlsx', sheet_name=f'f11', index=False) 
#df5.to_excel(f'output/df5.xlsx', sheet_name=f'f11', index=False) 
#df6.to_excel(f'output/df6.xlsx', sheet_name=f'f11', index=False) 
#df7.to_excel(f'output/df7-pap-0823.xlsx', sheet_name=f'f11', index=False)

# %%
df7 = pd.read_excel('input/db-pbi/f11/df7.xlsx', dtype='object')

# %%
df7.to_csv('input/db-pbi/f11/210830-df11_2.csv', sep=';', index=False)

# %% [markdown]
# # F11 directriz

# %%
emp = pd.read_excel('input/dirf11/empleados.xlsx', sheet_name='db')

# %%
usu = pd.read_excel('input/dirf11/usuarios.xlsx', sheet_name='db')

# %%
f11 = pd.read_csv('input/dirf11/210830-df11.csv', sep=';', dtype='object')

# %%
f11.head()
# Out:
#      Nro. F11 F03 Asociado   Nombre Cliente   Apellido Cliente RUT Cliente  \
# 0  1111092038                  CARLOS SIMON  CHIPIAJE BAUTISTA  1121874644
# 1  1111092021                  LUIS EDUARDO        MEJ�A VILLA    79491824
# 2  1111092014                        HERNAN            SALAZAR    71318921
# 3  1111092007                         LAURA              LOPEZ  1032479444
# 4  1111091994               MARIA DEL CARME              ROJAS    52550784
#
#                      Localidad         Local Fecha Creacisn Usuario Creacisn  \
# 0  VILLAVICENCIO VILLAVICENCIO  CD FALABELLA     30/08/2021         NCANTORB
# 1                BOGOTA BOGOTA  CD FALABELLA     30/08/2021         NCANTORB
# 2            MEDELLIN MEDELLIN  CD FALABELLA     30/08/2021         NCANTORB
# 3                BOGOTA BOGOTA  CD FALABELLA     30/08/2021         NCANTORB
# 4                BOGOTA BOGOTA  CD FALABELLA     30/08/2021         NCANTORB
#
#   Nro Confeccisn Fecha Terminal Secuencia Ticket Vendedor Tipo Servicio  \
# 0            NaN   NaN      NaN         1    NaN      NaN           NaN
# 1            NaN   NaN      NaN         1    NaN      NaN           NaN
# 2            NaN   NaN      NaN         1    NaN      NaN           NaN
# 3            NaN   NaN      NaN         1    NaN      NaN           NaN
# 4            NaN   NaN      NaN         1    NaN      NaN           NaN
#
#       RUT ST          Razsn Social       Marca         Desc. Marca  \
# 0  890100577               DEPRISA        VIVO                VIVO
# 1  830051440  EXXE LOG�STICA S.A.S     PYROREY             PYROREY
# 2  860016819      AL DIA LOGISTICA          LG                  LG
# 3  860512330      SERVIENTREGA S.A       SOFIA               SOFIA
# 4  900632226    MENSAJEROS URBANOS  AMERICAN T  AMERICAN TOURISTER
#
#                             Sucursal              Direccisn  Comuna  Ciudad  \
# 0             DEPRISA EXTRAVIADOS PV  AV EL DORADO # 59-15   BOGOTA  BOGOTA
# 1               EXXE EXTRAVIADOS PV                     NaN     NaN     NaN
# 2                  ALDIA AVERIAS PV                     NaN     NaN     NaN
# 3       SERVIENTREGA EXTRAVIADOS PV                     NaN     NaN     NaN
# 4  MENSAJEROS URBANOS ENTREGAS F PV                     NaN     NaN     NaN
#
#          Fono  Fax              Atencisn Dueqo Fecha Pactada  UPC Linea  \
# 0  3226101908  NaN  EDUARDO LUIS CAICEDO   NaN           NaN  NaN   NaN
# 1         NaN  NaN                   NaN   NaN           NaN  NaN   NaN
# 2         NaN  NaN                   NaN   NaN           NaN  NaN   NaN
# 3         NaN  NaN                   NaN   NaN           NaN  NaN   NaN
# 4         NaN  NaN                   NaN   NaN           NaN  NaN   NaN
#
#   Subclase  SKU Descripcisn Cantidad Nro Serie Precio Fecha Despacho  \
# 0      NaN  NaN         NaN      NaN       NaN    NaN            NaN
# 1      NaN  NaN         NaN      NaN       NaN    NaN            NaN
# 2      NaN  NaN         NaN      NaN       NaN    NaN            NaN
# 3      NaN  NaN         NaN      NaN       NaN    NaN            NaN
# 4      NaN  NaN         NaN      NaN       NaN    NaN            NaN
#
#   Usuario Despacho Fecha Entrega Usuario Entrega Fecha Retiro Usuario Retiro  \
# 0              NaN           NaN             NaN          NaN            NaN
# 1              NaN           NaN             NaN          NaN            NaN
# 2              NaN           NaN             NaN          NaN            NaN
# 3              NaN           NaN             NaN          NaN            NaN
# 4              NaN           NaN             NaN          NaN            NaN
#
#   Estado Sub Estado Cant.Impresisn O.Trabajo Presupuesto Observacion Patente  \
# 0    NaN        NaN            NaN       NaN         NaN         NaN     NaN
# 1    NaN        NaN            NaN       NaN         NaN         NaN     NaN
# 2    NaN        NaN            NaN       NaN         NaN         NaN     NaN
# 3    NaN        NaN            NaN       NaN         NaN         NaN     NaN
# 4    NaN        NaN            NaN       NaN         NaN         NaN     NaN
#
#   Rut Transp Nombre Transp
# 0        NaN           NaN
# 1        NaN           NaN
# 2        NaN           NaN
# 3        NaN           NaN
# 4        NaN           NaN

# %%
f11usua = f11.merge(usu, how='left', left_on='Usuario Creacisn', right_on='Nombre Usuario')

# %%
f11usua[f11usua['Nombre Usuario'].isna()]['Usuario Creacisn'].unique()
# Out:
# array([nan, 'ASOLARE', '29/07/2021', '12/08/2021'], dtype=object)

# %%
usu.drop_duplicates('Nombre Usuario', inplace=True)

# %%
usu.head()
# Out:
#                       Usuario Nombre Usuario         Rut         Fecha Estado  \
# 0           AARON DAVID AVILA        ADAVILA  1016006055  2019-09-19 00:00:00
# 5        AARON FELIPE CAMACHO      AFCAMACHO    80876303  2017-08-01 00:00:00
# 6  AASSENETH  PATRICIA ROLDAN        AROLDAN  1019095340  2018-06-24 00:00:00
# 7   AASSENETH PATRICIA ROLDON        AROLDON   101995340  2017-07-14 00:00:00
# 8                 ABEL LOZANO       ALOZANOU  1075626288  2020-09-10 00:00:00
#
#   Organizacion              Grupos       Estado         Fecha Creacion  \
# 0           CD     FALCO CD RECIBO       ACTIVO  2019-09-19 08:43:02.0
# 5     SANTA FE                      FINIQUITADO  2013-08-13 11:33:29.0
# 6     VEMPRESA  FALCO VE ASISTENTE  DESACTIVADO  2017-07-24 17:13:33.0
# 7     ADMINIST  FALCO VE ASISTENTE  FINIQUITADO  2017-06-13 09:50:48.0
# 8         SUBA    FALCO ASESOR SAC  DESACTIVADO  2020-08-10 11:15:16.0
#
#    Fecha ultimo Ingreso Unnamed: 9
# 0          sin registro        NaN
# 5          sin registro        NaN
# 6          sin registro        NaN
# 7          sin registro        NaN
# 8          sin registro        NaN

# %%
emp.drop_duplicates('Num_Documento', inplace=True)

# %%
f11res = f11usua.merge(emp, how='left', left_on='Rut', right_on='Num_Documento')

# %%
f11res.shape
# Out:
# (5233, 68)

# %%
f11res[f11res['Num_Documento'].isna()]['Nombre Usuario'].unique()
# Out:
# array(['ANDLEON', 'MROJASY', 'GPUERTAS', nan, 'YHERNANDC', 'FPEDRAZR',
#        'JINFANPO'], dtype=object)

# %%
f11res.head()
# Out:
#      Nro. F11 F03 Asociado   Nombre Cliente   Apellido Cliente RUT Cliente  \
# 0  1111092038                  CARLOS SIMON  CHIPIAJE BAUTISTA  1121874644
# 1  1111092021                  LUIS EDUARDO        MEJ�A VILLA    79491824
# 2  1111092014                        HERNAN            SALAZAR    71318921
# 3  1111092007                         LAURA              LOPEZ  1032479444
# 4  1111091994               MARIA DEL CARME              ROJAS    52550784
#
#                      Localidad         Local Fecha Creacisn Usuario Creacisn  \
# 0  VILLAVICENCIO VILLAVICENCIO  CD FALABELLA     30/08/2021         NCANTORB
# 1                BOGOTA BOGOTA  CD FALABELLA     30/08/2021         NCANTORB
# 2            MEDELLIN MEDELLIN  CD FALABELLA     30/08/2021         NCANTORB
# 3                BOGOTA BOGOTA  CD FALABELLA     30/08/2021         NCANTORB
# 4                BOGOTA BOGOTA  CD FALABELLA     30/08/2021         NCANTORB
#
#   Nro Confeccisn Fecha Terminal Secuencia Ticket Vendedor Tipo Servicio  \
# 0            NaN   NaN      NaN         1    NaN      NaN           NaN
# 1            NaN   NaN      NaN         1    NaN      NaN           NaN
# 2            NaN   NaN      NaN         1    NaN      NaN           NaN
# 3            NaN   NaN      NaN         1    NaN      NaN           NaN
# 4            NaN   NaN      NaN         1    NaN      NaN           NaN
#
#       RUT ST          Razsn Social       Marca         Desc. Marca  \
# 0  890100577               DEPRISA        VIVO                VIVO
# 1  830051440  EXXE LOG�STICA S.A.S     PYROREY             PYROREY
# 2  860016819      AL DIA LOGISTICA          LG                  LG
# 3  860512330      SERVIENTREGA S.A       SOFIA               SOFIA
# 4  900632226    MENSAJEROS URBANOS  AMERICAN T  AMERICAN TOURISTER
#
#                           Sucursal_x              Direccisn  Comuna  Ciudad  \
# 0             DEPRISA EXTRAVIADOS PV  AV EL DORADO # 59-15   BOGOTA  BOGOTA
# 1               EXXE EXTRAVIADOS PV                     NaN     NaN     NaN
# 2                  ALDIA AVERIAS PV                     NaN     NaN     NaN
# 3       SERVIENTREGA EXTRAVIADOS PV                     NaN     NaN     NaN
# 4  MENSAJEROS URBANOS ENTREGAS F PV                     NaN     NaN     NaN
#
#          Fono  Fax              Atencisn Dueqo Fecha Pactada  UPC Linea  \
# 0  3226101908  NaN  EDUARDO LUIS CAICEDO   NaN           NaN  NaN   NaN
# 1         NaN  NaN                   NaN   NaN           NaN  NaN   NaN
# 2         NaN  NaN                   NaN   NaN           NaN  NaN   NaN
# 3         NaN  NaN                   NaN   NaN           NaN  NaN   NaN
# 4         NaN  NaN                   NaN   NaN           NaN  NaN   NaN
#
#   Subclase  SKU Descripcisn Cantidad Nro Serie Precio Fecha Despacho  \
# 0      NaN  NaN         NaN      NaN       NaN    NaN            NaN
# 1      NaN  NaN         NaN      NaN       NaN    NaN            NaN
# 2      NaN  NaN         NaN      NaN       NaN    NaN            NaN
# 3      NaN  NaN         NaN      NaN       NaN    NaN            NaN
# 4      NaN  NaN         NaN      NaN       NaN    NaN            NaN
#
#   Usuario Despacho Fecha Entrega Usuario Entrega Fecha Retiro Usuario Retiro  \
# 0              NaN           NaN             NaN          NaN            NaN
# 1              NaN           NaN             NaN          NaN            NaN
# 2              NaN           NaN             NaN          NaN            NaN
# 3              NaN           NaN             NaN          NaN            NaN
# 4              NaN           NaN             NaN          NaN            NaN
#
#   Estado Sub Estado Cant.Impresisn O.Trabajo Presupuesto Observacion Patente  \
# 0    NaN        NaN            NaN       NaN         NaN         NaN     NaN
# 1    NaN        NaN            NaN       NaN         NaN         NaN     NaN
# 2    NaN        NaN            NaN       NaN         NaN         NaN     NaN
# 3    NaN        NaN            NaN       NaN         NaN         NaN     NaN
# 4    NaN        NaN            NaN       NaN         NaN         NaN     NaN
#
#   Rut Transp Nombre Transp        Usuario Nombre Usuario         Rut  \
# 0        NaN           NaN  NESTOR CANTOR       NCANTORB  1012346396
# 1        NaN           NaN  NESTOR CANTOR       NCANTORB  1012346396
# 2        NaN           NaN  NESTOR CANTOR       NCANTORB  1012346396
# 3        NaN           NaN  NESTOR CANTOR       NCANTORB  1012346396
# 4        NaN           NaN  NESTOR CANTOR       NCANTORB  1012346396
#
#           Fecha Estado Organizacion                       Grupos  Estado  \
# 0  2020-09-18 00:00:00       FALCOL  FALCO CD ANALISTA DESPACHOS  ACTIVO
# 1  2020-09-18 00:00:00       FALCOL  FALCO CD ANALISTA DESPACHOS  ACTIVO
# 2  2020-09-18 00:00:00       FALCOL  FALCO CD ANALISTA DESPACHOS  ACTIVO
# 3  2020-09-18 00:00:00       FALCOL  FALCO CD ANALISTA DESPACHOS  ACTIVO
# 4  2020-09-18 00:00:00       FALCOL  FALCO CD ANALISTA DESPACHOS  ACTIVO
#
#           Fecha Creacion  Fecha ultimo Ingreso Unnamed: 9 Cod_Empleado  \
# 0  2020-09-18 12:37:50.0          sin registro        NaN       119040
# 1  2020-09-18 12:37:50.0          sin registro        NaN       119040
# 2  2020-09-18 12:37:50.0          sin registro        NaN       119040
# 3  2020-09-18 12:37:50.0          sin registro        NaN       119040
# 4  2020-09-18 12:37:50.0          sin registro        NaN       119040
#
#    Num_Documento                nombre completo  \
# 0   1.012346e+09  NELSON ANTONIO CANTOR BELTRAN
# 1   1.012346e+09  NELSON ANTONIO CANTOR BELTRAN
# 2   1.012346e+09  NELSON ANTONIO CANTOR BELTRAN
# 3   1.012346e+09  NELSON ANTONIO CANTOR BELTRAN
# 4   1.012346e+09  NELSON ANTONIO CANTOR BELTRAN
#
#                            Sucursal_y               Cargo    Tipo
# 0  FALABELLA - CENTRO DE DISTRIBUCION  ANALISTA POSTVENTA  planta
# 1  FALABELLA - CENTRO DE DISTRIBUCION  ANALISTA POSTVENTA  planta
# 2  FALABELLA - CENTRO DE DISTRIBUCION  ANALISTA POSTVENTA  planta
# 3  FALABELLA - CENTRO DE DISTRIBUCION  ANALISTA POSTVENTA  planta
# 4  FALABELLA - CENTRO DE DISTRIBUCION  ANALISTA POSTVENTA  planta

# %%
f11res[f11res['Num_Documento'].notna()].shape
# Out:
# (4195, 68)

# %%
f11res.to_excel('input/dirf11/210830-data_directriz_f11.xlsx', sheet_name='gco', index=False)
